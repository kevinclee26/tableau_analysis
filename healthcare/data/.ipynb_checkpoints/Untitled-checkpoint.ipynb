# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Inpatient_Psychiatric_Facility_Quality_Measure_Data___by_Facility.csv')
df.columns
drop_cols=['HBIPS-2_Measure_Description', 
           'HBIPS-2_Overall_Footnote', 
           'HBIPS-3_Measure_Description', 
           'HBIPS-3_Overall_Footnote', 
           'HBIPS-5_Measure_Description', 
           'HBIPS-5_Overall_Footnote', 
           'HBIPS-6_Measure_Description', 
           'HBIPS-6_Overall_Footnote', 
           'HBIPS-7_Measure_Description', 
           'HBIPS-7_Overall_Footnote', 
           'SUB-1_Measure_Description', 
           'SUB-1_Footnote', 
           'TOB-1_Measure_Description', 
           'TOB-1_Footnote', 
           'TOB-2/-2a_Measure_Desc', 
           'TOB-2_Footnote', 
           'PEoC_Assessed_Footnote', 
           'EHR_Use_Measure_Description', 
           'EHR_Use_Footnote', 
           'HIE_Measure_Description', 
           'HIE_Footnote', 
           'Start_Date', 
           'End_Date', 
           'FUH_Measure_Description', 
           'FUH-30_Footnote', 
           'FUH_Measure_Start_Date', 
           'FUH_Measure_End_Date', 
           'IMM-2_Measure_Description', 
           'IMM-2_Footnote', 
           'HCP_Measure_Description', 
           'HCP_%', 
           'HCP_Numerator', 
           'HCP_Denominator', 
           'HCP_Footnote', 
           'Flu_Season_Start_Date', 
           'Flu_Season_End_Date']
# Out:
# Index(['Provider_Number', 'Hospital_Name', 'Address', 'City', 'State',
#        'ZIP_Code', 'County_Name', 'HBIPS-2_Measure_Description',
#        'HBIPS-2_Overall_Rate_Per_1000', 'HBIPS-2_Overall_Num',
#        'HBIPS-2_Overall_Den', 'HBIPS-2_Overall_Footnote',
#        'HBIPS-3_Measure_Description', 'HBIPS-3_Overall_Rate_Per_1000',
#        'HBIPS-3_Overall_Num', 'HBIPS-3_Overall_Den',
#        'HBIPS-3_Overall_Footnote', 'HBIPS-5_Measure_Description',
#        'HBIPS-5_Overall_%_of_Total', 'HBIPS-5_Overall_Num',
#        'HBIPS-5_Overall_Den', 'HBIPS-5_Overall_Footnote',
#        'HBIPS-6_Measure_Description', 'HBIPS-6_Overall_%_of_Total',
#        'HBIPS-6_Overall_Num', 'HBIPS-6_Overall_Den',
#        'HBIPS-6_Overall_Footnote', 'HBIPS-7_Measure_Description',
#        'HBIPS-7_Overall_%_of_Total', 'HBIPS-7_Overall_Num',
#        'HBIPS-7_Overall_Den', 'HBIPS-7_Overall_Footnote',
#        'SUB-1_Measure_Description', 'SUB-1_%', 'SUB-1_Numerator',
#        'SUB-1_Denominator', 'SUB-1_Footnote', 'TOB-1_Measure_Description',
#        'TOB-1_%', 'TOB-1_Numerator', 'TOB-1_Denominator', 'TOB-1_Footnote',
#        'TOB-2/-2a_Measure_Desc', 'TOB-2_%', 'TOB-2_Numerator',
#        'TOB-2/-2a_Denominator', 'TOB-2_Footnote', 'TOB-2a_%',
#        'TOB-2a_Numerator', 'TOB-2/-2a__Denominator', 'TOB-2a_Footnote',
#        'PEoC_Measure_Description', 'PEoC_Assessed_Response',
#        'PEoC_Assessed_Footnote', 'EHR_Use_Measure_Description',
#        'EHR_Use_Response', 'EHR_Use_Footnote', 'HIE_Measure_Description',
#        'HIE_Response', 'HIE_Footnote', 'Start_Date', 'End_Date',
#        'FUH_Measure_Description', 'FUH-30_%', 'FUH-30_Numerator',
#        'FUH-30_Denominator', 'FUH-30_Footnote', 'FUH-7_%', 'FUH-7_Numerator',
#        'FUH-7_Denominator', 'FUH-7_Footnote', 'FUH_Measure_Start_Date',
#        'FUH_Measure_End_Date', 'IMM-2_Measure_Description', 'IMM-2_%',
#        'IMM-2_Numerator', 'IMM-2_Denominator', 'IMM-2_Footnote',
#        'HCP_Measure_Description', 'HCP_%', 'HCP_Numerator', 'HCP_Denominator',
#        'HCP_Footnote', 'Flu_Season_Start_Date', 'Flu_Season_End_Date'],
#       dtype='object')

# %%
df
# Out:
#       Provider_Number                            Hospital_Name  \
# 0               10007                 MIZELL MEMORIAL HOSPITAL
# 1               10008              CRENSHAW COMMUNITY HOSPITAL
# 2               10011                       ST. VINCENT'S EAST
# 3               10012           DEKALB REGIONAL MEDICAL CENTER
# 4               10016            SHELBY BAPTIST MEDICAL CENTER
# ...               ...                                      ...
# 1639           534001                   WYOMING STATE HOSPITAL
# 1640           534004             WYOMING BEHAVIORAL INSTITUTE
# 1641           670010                         MAYHILL HOSPITAL
# 1642           670072                      HOPEBRIDGE HOSPITAL
# 1643           670093  ASPIRE BEHAVIORAL HEALTH OF CONROE, LLC
#
#                                    Address        City State  ZIP_Code  \
# 0            702 N MAIN STREET PO BOX 1010         OPP    AL     36467
# 1                     101 HOSPITAL CIRCLE      LUVERNE    AL     36049
# 2              50 MEDICAL PARK EAST DRIVE   BIRMINGHAM    AL     35235
# 3                    200 MED CENTER DRIVE   FORT PAYNE    AL     35968
# 4                 1000 FIRST STREET NORTH    ALABASTER    AL     35007
# ...                                    ...         ...   ...       ...
# 1639                    831 HWY 150 SOUTH     EVANSTON    WY     82931
# 1640                2521 EAST 15TH STREET       CASPER    WY     82609
# 1641              2809 SOUTH MAYHILL ROAD       DENTON    TX     76208
# 1642                    5556 GASMER DRIVE      HOUSTON    TX     77035
# 1643  2006 SOUTH LOOP 336 WEST, SUITE 500       CONROE    TX     77304
#
#      County_Name      HBIPS-2_Measure_Description  \
# 0      Covington  Hours of physical-restraint use
# 1       Crenshaw  Hours of physical-restraint use
# 2      Jefferson  Hours of physical-restraint use
# 3         DeKalb  Hours of physical-restraint use
# 4         Shelby  Hours of physical-restraint use
# ...          ...                              ...
# 1639       Uinta  Hours of physical-restraint use
# 1640     Natrona  Hours of physical-restraint use
# 1641      Denton  Hours of physical-restraint use
# 1642      Harris  Hours of physical-restraint use
# 1643  Montgomery  Hours of physical-restraint use
#
#       HBIPS-2_Overall_Rate_Per_1000  HBIPS-2_Overall_Num  ...  \
# 0                              0.00                 0.00  ...
# 1                              0.44                59.63  ...
# 2                              0.00                 0.00  ...
# 3                              0.00                 0.00  ...
# 4                              0.11                41.02  ...
# ...                             ...                  ...  ...
# 1639                            NaN                  NaN  ...
# 1640                           0.04                23.35  ...
# 1641                           0.03                11.56  ...
# 1642                           0.01                 5.11  ...
# 1643                           0.00                 0.08  ...
#
#       IMM-2_Numerator  IMM-2_Denominator IMM-2_Footnote  \
# 0                  50                128            NaN
# 1                  88                 88            NaN
# 2                  54                 80            NaN
# 3                 105                106            NaN
# 4                 171                171            NaN
# ...               ...                ...            ...
# 1639    Not Available      Not Available            5.0
# 1640              301                304            NaN
# 1641              285                340            NaN
# 1642                0               2372            NaN
# 1643    Not Available      Not Available            1.0
#
#                          HCP_Measure_Description          HCP_%  \
# 0     Healthcare Personnel Influenza Vaccination             54
# 1     Healthcare Personnel Influenza Vaccination             34
# 2     Healthcare Personnel Influenza Vaccination             42
# 3     Healthcare Personnel Influenza Vaccination            100
# 4     Healthcare Personnel Influenza Vaccination             71
# ...                                          ...            ...
# 1639  Healthcare Personnel Influenza Vaccination  Not Available
# 1640  Healthcare Personnel Influenza Vaccination             91
# 1641  Healthcare Personnel Influenza Vaccination             59
# 1642  Healthcare Personnel Influenza Vaccination             23
# 1643  Healthcare Personnel Influenza Vaccination             77
#
#       HCP_Numerator  HCP_Denominator HCP_Footnote  Flu_Season_Start_Date  \
# 0                15               28          NaN             10/01/2015
# 1                15               44          NaN             10/01/2015
# 2                14               33          NaN             10/01/2015
# 3                54               54          NaN             10/01/2015
# 4                65               92          NaN             10/01/2015
# ...             ...              ...          ...                    ...
# 1639  Not Available    Not Available          5.0             10/01/2015
# 1640            262              288          NaN             10/01/2015
# 1641            115              194          NaN             10/01/2015
# 1642             57              249          NaN             10/01/2015
# 1643            252              326          NaN             10/01/2015
#
#      Flu_Season_End_Date
# 0             03/31/2016
# 1             03/31/2016
# 2             03/31/2016
# 3             03/31/2016
# 4             03/31/2016
# ...                  ...
# 1639          03/31/2016
# 1640          03/31/2016
# 1641          03/31/2016
# 1642          03/31/2016
# 1643          03/31/2016
#
# [1644 rows x 85 columns]

# %%
metric_cols=['HBIPS-2_Overall_Rate_Per_1000', 
             'HBIPS-3_Overall_Rate_Per_1000', 
             'HBIPS-5_Overall_%_of_Total', 
             'HBIPS-6_Overall_%_of_Total', 
             'HBIPS-7_Overall_%_of_Total']
for each_col in metric_cols: 
    if df[each_col].dtype=='O': 
        df[each_col]=pd.to_numeric(df[each_col].str.replace('%', ''), errors='coerce')

# %%
df[metric_cols].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5efbb37f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5ef0402e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5ef4f0860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5ef062dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5ef092390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5ef0b8908>]],
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
# new_df=pd.DataFrame(scaler.fit_transform(df[metric_cols]))
df[metric_cols]=pd.DataFrame(scaler.fit_transform(df[metric_cols]))

# %%
sn.heatmap(df[metric_cols].corr())

# %%
import seaborn as sn
sn.heatmap(new_df.corr())

# %%
new_df.corr()
# Out:
#           0         1         2         3         4
# 0  1.000000  0.962095  0.020844  0.000847 -0.002177
# 1  0.962095  1.000000  0.030941  0.000158 -0.003532
# 2  0.020844  0.030941  1.000000  0.273543  0.341227
# 3  0.000847  0.000158  0.273543  1.000000  0.857414
# 4 -0.002177 -0.003532  0.341227  0.857414  1.000000

# %%
new_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2cc8cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2cfac50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2d11208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2d37780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2deecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5f2e1d2b0>]],
#       dtype=object)

# %%
new_df[0].max()
# Out:
# 39.172179538158964
